# %% [markdown]
# # Draw thee Pixhawk flight path

# %%
import numpy as np
import pandas as pd
import folium as f
import matplotlib.pyplot as plt
from folium import plugins

# %%
f.__version__
# Out:
# '0.14.0'

# %%
df=pd.read_csv('data/07_51_52_vehicle_global_position_0.csv')

# %%
df
# Out:
#       timestamp        lat         lon       alt  alt_ellipsoid  delta_alt  \
# 0      80835159  36.653821  126.296702 -2.094273      15.780431       -0.0
# 1      81035960  36.653821  126.296702 -2.087732      15.789333       -0.0
# 2      81244759  36.653820  126.296703 -2.084309      15.794419       -0.0
# 3      81445559  36.653820  126.296703 -2.079809      15.800413       -0.0
# 4      81645559  36.653820  126.296703 -2.083391      15.798643       -0.0
# ...         ...        ...         ...       ...            ...        ...
# 3418  776026359  36.653801  126.296696 -1.954914      14.945698       -0.0
# 3419  776227961  36.653801  126.296696 -1.953750      14.966935       -0.0
# 3420  776428759  36.653801  126.296696 -1.951881      15.008204       -0.0
# 3421  776628759  36.653801  126.296696 -1.952118      15.028078       -0.0
# 3422  776834359  36.653801  126.296696 -1.956729      15.043471       -0.0
#
# ...

# %%
df[["lat", "lon"]].plot.scatter(x="lat", y="lon", figsize=(50, 50), grid=True)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='lon'>

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1)
axes1.set_title('Flight Path')
axes1.set_xlabel('X-m') 
axes1.set_ylabel('Y-m')

data = pd.DataFrame(['lat'],['lon'])
lat = (df['lat'])
lon = (df['lon'])
plt.plot(lat, lon)
plt.show()

# %%
center = [36.653, 126.296]
m = f.Map(location=center, zoom_start=17)

for i in df.index[:df.shape[0]]:
    print (df.loc[i, ['lat', 'lon']])

m
# Out:
# lat     36.653821
# lon    126.296702
# Name: 0, dtype: float64
# lat     36.653821
# lon    126.296702
# Name: 1, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 2, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 3, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 4, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 5, dtype: float64
# lat     36.653820
# lon    126.296704
# Name: 6, dtype: float64
# lat     36.653820
# lon    126.296704
# Name: 7, dtype: float64
# lat     36.653820
# lon    126.296704
# Name: 8, dtype: float64
# lat     36.653819
# lon    126.296704
# Name: 9, dtype: float64
# lat     36.653819
# lon    126.296704
# Name: 10, dtype: float64
# lat     36.653819
# lon    126.296705
# Name: 11, dtype: float64
# lat     36.653819
# lon    126.296705
# Name: 12, dtype: float64
# lat     36.653819
# lon    126.296705
# Name: 13, dtype: float64
# lat     36.653818
# lon    126.296705
# Name: 14, dtype: float64
# ...

# %%
center = df.loc[0, ['lat', 'lon']]
print(center)

m = f.Map(location=center, zoom_start=17)

print(df.shape[0])
for i in df.index[:df.shape[0]]:
    location = df.loc[i, ['lat', 'lon']]
    print(location)
m
# Out:
# lat     36.653821
# lon    126.296702
# Name: 0, dtype: float64
# 3423
# lat     36.653821
# lon    126.296702
# Name: 0, dtype: float64
# lat     36.653821
# lon    126.296702
# Name: 1, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 2, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 3, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 4, dtype: float64
# lat     36.653820
# lon    126.296703
# Name: 5, dtype: float64
# lat     36.653820
# lon    126.296704
# Name: 6, dtype: float64
# lat     36.653820
# lon    126.296704
# Name: 7, dtype: float64
# lat     36.653820
# lon    126.296704
# Name: 8, dtype: float64
# lat     36.653819
# lon    126.296704
# Name: 9, dtype: float64
# lat     36.653819
# lon    126.296704
# Name: 10, dtype: float64
# lat     36.653819
# lon    126.296705
# Name: 11, dtype: float64
# lat     36.653819
# lon    126.296705
# Name: 12, dtype: float64
# lat     36.653819
# lon    126.296705
# ...

# %%
center = [df.lat.mean(), df.lon.mean()]  #위도 경도 평균값을 중앙좌표로
# min(), max() 가장 동쪽과 서쪽, 남쪽과 북쪽을 중앙에 둘수 있다.
m = f.Map(location=center, zoom_start=16)

for i in df.index[:len(df)]:
    lat = df.loc[i, 'lat']
    long = df.loc[i,'lon']
    f.Circle([lat,long],
        color = 'red',
        radius = 0.1,
        fill=True
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
