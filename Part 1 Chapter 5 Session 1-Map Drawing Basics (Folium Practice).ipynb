# %% [markdown]
# # 지도 시각화 - 포리움(Folium)의 설치 및 활용

# %%
pip install folium

# %%
pip install branca
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install input
# Out:
# ...
#   Created wheel for input: filename=input-0.0.0-py3-none-any.whl size=945 sha256=fae23bd067653f862acef00dc7735465c196a37da69d02246f213c61bd604357
#   Stored in directory: c:\users\dovejlee\appdata\local\pip\cache\wheels\0a\60\2b\b8b05f7461ab53e63e82521f24a4178bf4c758204637733e11
# Successfully built input
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install objects
# Out:
# ...
#   Created wheel for objects: filename=objects-0.3.1-py3-none-any.whl size=2175 sha256=dd2006e14493448ae0520aaa37a6a55e0443139a8f0c4ba16793c2357b30a74c
#   Stored in directory: c:\users\dovejlee\appdata\local\pip\cache\wheels\4e\88\5c\b4db10bcf303cd453046b9de2a51f9e812bf7984963e55827d
# Successfully built objects
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import json
import requests
import branca
import folium

# %%
m = folium.Map(location = [36.59533952408117, 126.29442554748438])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save('map.html')

# %% [markdown]
# # 초기 화면의 크기를 지정하는 방법은 ‘zoom_start’ 속성을 주면 가능하다.¶

# %%
HanseoUniv=[36.59533952408117, 126.29442554748438]
folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=15)  # 15
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
HanseoUniv=[36.59533952408117, 126.29442554748438]
folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=15)  # 15
folium.Marker(
    location = HanseoUniv,
    popup="한서대",
    icon = folium.Icon(color="blue", icon ="star")
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
HanseoUniv=[36.59533952408117, 126.29442554748438]
folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=15)  # 15
folium.Marker(
    location = HanseoUniv,
    popup="한서대",
    icon = folium.Icon(color="blue", icon ="star")
    ).add_to(m)
folium.CircleMarker(
    location = HanseoUniv,
    radius=20,
    color = '#FFF',
    fil_color= "#fffggg",
    popup="한서대태안캠퍼스",
    icon= folium.Icon(color="green", icon= "star")
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#마커
HanseoUniv=[36.59533952408117, 126.29442554748438]
NaMoonJae= [36.5869785, 126.375217]
KkotJiBeach = [36.500569, 126.3373923]
SeosanSportsComplex = [36.79714342592591, 126.43311181481478]
CheongPoDae=[36.63972121453488, 126.30102826869934]

m = folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=9)
tooltip = 'Click me!'

folium.Marker(HanseoUniv,
             popup='<b> 한서대학교 태안캠퍼스</b>',
             tooltip=tooltip
).add_to(m)

folium.Marker(NaMoonJae,
             popup='<b> 나문재</b>',
             tooltip=tooltip
).add_to(m)

folium.Marker(KkotJiBeach,
             popup='<b> 꽃지해수욕장</b>',
             tooltip=tooltip
).add_to(m)

folium.Marker(SeosanSportsComplex,
             popup='<b> 서산종합운동장 </b>',
             tooltip=tooltip
).add_to(m)


folium.Marker(CheongPoDae,
             popup='<b> 청포대 해수욕장</b>',
             tooltip=tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium import plugins

HanseoUniv=[36.59533952408117, 126.29442554748438]
CheongPoDae=[36.63972121453488, 126.30102826869934]
NaMoonJae= [36.5869785, 126.375217]
SeosanSportsComplex = [36.79714342592591, 126.43311181481478]
KkotJiBeach = [36.500569, 126.3373923]

m = folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=9)

folium.Marker(
    CheongPoDae,
    popup='<b>청포대 해수욕장<b>',
    icon=folium.Icon(color='blue', icon='flag')
).add_to(m)

folium.Marker(
    KkotJiBeach,
    popup='<b>꽃지해수욕장<b>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    SeosanSportsComplex,
    popup='<b>서산종합운동장<b>',
    icon=folium.Icon(color='beige', icon='star')
    # warning color = yellow 
).add_to(m)

folium.Marker(
    NaMoonJae,
    popup='<b>나문재<b>',
    icon=folium.Icon(color='green', icon='bookmark')
).add_to(m)

folium.Marker(
    HanseoUniv,
    popup='<b>한서대학교비행장<b>',
    icon=folium.Icon(color='orange', icon='home')
).add_to(m)
# icon이 소문자인 이유
# Ioon이 대문자인 이유
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#보트마커
m = folium.Map([36.5,126], zoom_starts=7)

SEA = [36.54626436633822, 126.22198816402707]

plugins.BoatMarker(
    location=SEA,
    heading=90,                # degree
    wind_heading=120,          #
    wind_speed=100,
    color='yellow'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#클릭마커
HanseoUniv = [36.59533952408117, 126.29442554748438]

m = folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=12)

folium.Marker(
    HanseoUniv,
    popup='Hanseo University(TAean Campus)'
).add_to(m)

m.add_child(folium.ClickForMarker(popup='Marker'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#원(circle)
HanseoUniv = [36.59533952408117, 126.29442554748438]
NaMoonJae= [36.5869785, 126.375217]
KkotJiBeach = [36.500569, 126.3373923]
SeosanSportsComplex = [36.79714342592591, 126.43311181481478]
CheongPoDae=[36.63972121453488, 126.30102826869934]

m = folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start= 9)

folium.Circle(HanseoUniv,
             popup='<b> Hanseo University </b>',
             radius=1000,
             color='darkblue',
             fill=True,
             fill_color='darkblue'
).add_to(m)


folium.Circle(NaMoonJae,
             popup='<b> Na Moon Jae</b>',
             radius=300,
             color='royalblue',
             fill=True
).add_to(m)

folium.Circle(SeosanSportsComplex,
             popup='<b> Seosan Sports Complex</b>',
             radius=300,
             color='royalblue',
             fill=True
).add_to(m)

folium.Circle(KkotJiBeach,
             popup='<b> Kkot Ji Beach</b>',
             radius=300,
             color='royalblue',
             fill=True
).add_to(m)

folium.Circle(CheongPoDae,
             popup='<b> Cheong Po Dae</b>',
             radius=300,
             color='royalblue',
             fill=True
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 대한민국 행정구역 다운로드 페이지 에서 자료 다운
# # QGIS 설치하여 지도 영역 json파일로 만들기
# # 지역 법적동 확인- 태안 44825
# # mapshaping mapshaper.org
# # https://www.youtube.com/watch?v=c0EQWKN5kh4

# %%
HanseoUniv=[36.59533952408117, 126.29442554748438]

folium.Map(
    location = HanseoUniv,
    tiles='Stamen Terrain',
    zoom_start=15)  # 15

geo_data = 'TAEAN.geojson'
with open(geo_data, mode='rt', encoding='utf-8') as f:
    geo = json.loads(f.read())
    f.close()
folium.GeoJson(
    geo,
    name='TAEAN_GEO_DATA'
).add_to(m)

folium.Marker(
    location = HanseoUniv,
    popup="한서대",
    icon = folium.Icon(color="blue", icon ="star")
    ).add_to(m)
folium.CircleMarker(
    location = HanseoUniv,
    radius=20,
    color = '#FFF',
    fil_color= "#fffggg",
    popup="한서대태안캠퍼스",
    icon= folium.Icon(color="green", icon= "star")
    ).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [16], in <cell line: 9>()
#       3 folium.Map(
#       4     location = HanseoUniv,
#       5     tiles='Stamen Terrain',
#       6     zoom_start=15)  # 15
#       8 geo_data = 'TAEAN.geojson'
# ----> 9 with open(geo_data, mode='rt', encoding='utf-8') as f:
#      10     geo = json.loads(f.read())
#      11     f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TAEAN.geojson'

# %%
Seoul = [37.566687, 126.978417]
Busan = [35.179774, 129.075004]
Incheon = [37.455900, 126.705522]
DaeGu = [35.871380, 128.601743]
DaeJeon = [36.350451, 127.384827]
KwangJu = [35.160072, 126.851440]
Cities = [Seoul, Busan,Incheon, DaeGu, DaeJeon, KwangJu]

# %%
len(Cities)
# Out:
# 6

# %%
Cities
# Out:
# [[37.566687, 126.978417],
#  [35.179774, 129.075004],
#  [37.4559, 126.705522],
#  [35.87138, 128.601743],
#  [36.350451, 127.384827],
#  [35.160072, 126.85144]]

# %%
range(len(Cities))
# Out:
# range(0, 6)

# %%
for i in range(len(Cities)):
    print(i, "th")
    print(Cities[i])
# Out:
# 0 th
# [37.566687, 126.978417]
# 1 th
# [35.179774, 129.075004]
# 2 th
# [37.4559, 126.705522]
# 3 th
# [35.87138, 128.601743]
# 4 th
# [36.350451, 127.384827]
# 5 th
# [35.160072, 126.85144]

# %%
Seoul = [37.566687, 126.978417]
Busan = [35.179774, 129.075004]
Incheon = [37.455900, 126.705522]
DaeGu = [35.871380, 128.601743]
DaeJeon = [36.350451, 127.384827]
KwangJu = [35.160072, 126.851440]
Cities = [Seoul, Busan,Incheon, DaeGu, DaeJeon, KwangJu]

m = folium.Map(
    location = [36.577629, 127.770135],
    tiles='Stamen Terrain',
    zoom_start=7)

for i in range(len(Cities)):
    folium.CircleMarker(
        location=Cities[i],
        radius=10,
        color='red'
    ).add_to(m)   
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#폴리라인
SouthCenter = [36.577629, 127.770135]
m = folium.Map(
    location = SouthCenter,
    zoom_start=7)

folium.PolyLine(
    locations=Cities,
    tooltip='PolyLine'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
SouthCenter = [36.577629, 127.770135]

m = folium.Map(
    location = SouthCenter,
    zoom_start=7)

folium.Rectangle(
    bounds=Cities,
    tooltip='Rectangle'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
SouthCenter = [36.577629, 127.770135]
m = folium.Map(
    location = SouthCenter,
    zoom_start=7)

folium.Polygon(
    locations=Cities,
    fill=True,
    tooltip='Rectangle'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map([37,127], zoom_start=5)

wind_positions=[[32.587385, 133.058046],
                [34.359654, 130.083293],
                [35.570943, 127.200923],
                [36.214572, 124.226170],
                [36.348622, 121.916579],
                [36.645685, 117.981036]]
#2차원 의 행렬 

wind_line = folium.PolyLine(
    wind_positions,
    weight=10,
    color='deepskyblue'
).add_to(m)

plugins.PolyLineTextPath(
    wind_line,
    '> ',
    repeat=True,
    # False/True
    offset=5,
    # change the offset 7, 10, 
    attributes={'fill': 'dodgerblue', 'front_weight': 'bold', 'front-size': '24'}
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
marine_currents=[[42.235235, 131.951693],
                 [41.391475, 130.442223],
                 [39.775207, 128.887468],
                 [38.758520, 128.691237],
                 [37.571772, 129.385593],
                 [36.256336, 129.778056]]
m= folium.Map()

folium.plugins.AntPath(
    locations=marine_currents,
    reverse='True',
    #True/False
    dash_array=[20,20]
).add_to(m)

m.fit_bounds(m.get_bounds())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# folium.Marker(HanseoUniv, popup='Plane', icon='star').add_to(m)

# %%
HanseoUniv = [36.59533952408117, 126.29442554748438]
NaMoonJae= [36.5869785, 126.375217]
KkotJiBeach = [36.500569, 126.3373923]
CheongPoDae=[36.63972121453488, 126.30102826869934]

m=folium.Map(location=HanseoUniv,zoom_starts=6)

gs=folium.FeatureGroup(name='Groups')
m.add_child(gs)
g1 = plugins.FeatureGroupSubGroup(gs,'Group1')
m.add_child(g1)
g2 = plugins.FeatureGroupSubGroup(gs,'Group2')
m.add_child(g2)

folium.Marker(NaMoonJae).add_to(g1)
folium.Marker(KkotJiBeach).add_to(g1)
folium.Marker(CheongPoDae).add_to(g2)
#folium.Marker([2,-2]).add_to(g1)
folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
