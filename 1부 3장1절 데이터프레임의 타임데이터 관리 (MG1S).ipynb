# %%
# 데이타 분석을 위한 파나스 입문 3-5절 참조

# %%
from datetime import datetime
import pandas as pd

# %%
pd.options.display.float_format = '{:.8f}'.format

# %%
MG1S_df=pd.read_csv('2021_04_15_MG1S.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (162,163,164,165,166,167,168,169,170,171,242) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(MG1S_df.head())
# Out:
#    Clock:Tick#  Clock:offsetTime  IMU_ATTI(0):Longitude[degrees [-180;180]]  \
# 0    184013124      -92.57000000                                        nan
# 1    184170945      -92.53600000                                        nan
# 2    184328651      -92.50200000                                        nan
# 3    184485197      -92.46900000                                        nan
# 4    184642037      -92.43500000                                        nan
#
#    IMU_ATTI(0):Latitude[degrees [-180;180]]  IMU_ATTI(0):press:D[meters]  \
# 0                                       nan                 -43.76210000
# 1                                       nan                 -43.56128300
# 2                                       nan                 -44.03161600
# 3                                       nan                 -43.99991000
# 4                                       nan                 -43.48729700
#
#    IMU_ATTI(0):alti:D[meters]  IMU_ATTI(0):relativeHeight:C[meters]  \
# 0                -44.09289000                                   nan
# 1                -44.09327300                                   nan
# 2                -44.07071700                                   nan
# 3                -44.05832000                                   nan
# 4                -44.05737700                                   nan
#
#    IMU_ATTI(0):absoluteHeight:C[meters]  IMU_ATTI(0):numSats  \
# 0                                   nan                    8
# 1                                   nan                    8
# 2                                   nan                    8
# 3                                   nan                    8
# 4                                   nan                    8
#
#    IMU_ATTI(0):roll:C[degrees [-180;180]]  ...  BatteryInfo:BatCurrent:D  \
# 0                             -0.34243875  ...                      -620
# 1                             -0.34326232  ...                      -620
# 2                             -0.34092792  ...                      -620
# 3                             -0.34247673  ...                      -620
# 4                             -0.30563588  ...                      -620
#
#    BatteryInfo:BatCap:D  BatteryInfo:CapPercnt:D  BatteryInfo:BatTemp:D  \
# 0                  9652                       92                    329
# 1                  9652                       92                    329
# 2                  9652                       92                    329
# 3                  9652                       92                    329
# 4                  9652                       92                    329
#
#    BatteryInfo:BatAuth:D  BatteryInfo:BatDataCnt:D  BatteryInfo:FullCap:D  \
# 0                      1                        31                  10464
# 1                      1                        31                  10464
# 2                      1                        31                  10464
# 3                      1                        31                  10464
# 4                      1                        31                  10464
#
#                   Attribute|Value  ConvertDatV3  4.2.1
# 0      Firmware Date| Feb 26 2019           nan    nan
# 1                  ACType|UNKNOWN           nan    nan
# 2  dateTime|2021-4-15 2:18:10 GMT           nan    nan
# 3                             NaN           nan    nan
# 4                             NaN           nan    nan
#
# [5 rows x 245 columns]

# %%
print(MG1S_df.columns)
# Out:
# Index(['Clock:Tick#', 'Clock:offsetTime',
#        'IMU_ATTI(0):Longitude[degrees [-180;180]]',
#        'IMU_ATTI(0):Latitude[degrees [-180;180]]',
#        'IMU_ATTI(0):press:D[meters]', 'IMU_ATTI(0):alti:D[meters]',
#        'IMU_ATTI(0):relativeHeight:C[meters]',
#        'IMU_ATTI(0):absoluteHeight:C[meters]', 'IMU_ATTI(0):numSats',
#        'IMU_ATTI(0):roll:C[degrees [-180;180]]',
#        ...
#        'BatteryInfo:BatCurrent:D', 'BatteryInfo:BatCap:D',
#        'BatteryInfo:CapPercnt:D', 'BatteryInfo:BatTemp:D',
#        'BatteryInfo:BatAuth:D', 'BatteryInfo:BatDataCnt:D',
#        'BatteryInfo:FullCap:D', 'Attribute|Value', 'ConvertDatV3', '4.2.1'],
#       dtype='object', length=245)

# %%
print(MG1S_df['GPS:Time'].dtype)
# Out:
# int64

# %%
MG1S_df['GPS:Time']
#column BY
# Out:
# 0        21828
# 1        21828
# 2        21828
# 3        21828
# 4        21828
#          ...
# 25261    23235
# 25262    23235
# 25263    23235
# 25264    23235
# 25265    23235
# Name: GPS:Time, Length: 25266, dtype: int64

# %%
MG1S_df
# Out:
#        Clock:Tick#  Clock:offsetTime  \
# 0        184013124      -92.57000000
# 1        184170945      -92.53600000
# 2        184328651      -92.50200000
# 3        184485197      -92.46900000
# 4        184642037      -92.43500000
# ...            ...               ...
# 25261   4152113966      754.31800000
# 25262   4152272282      754.35200000
# 25263   4152429189      754.38500000
# 25264   4152585914      754.41900000
# 25265   4152742149      754.45200000
#
#        IMU_ATTI(0):Longitude[degrees [-180;180]]  \
# 0                                            nan
# 1                                            nan
# 2                                            nan
# 3                                            nan
# 4                                            nan
# ...                                          ...
# 25261                               127.11473030
# 25262                               127.11473030
# 25263                               127.11473030
# 25264                               127.11473020
# 25265                               127.11473020
#
#        IMU_ATTI(0):Latitude[degrees [-180;180]]  IMU_ATTI(0):press:D[meters]  \
# 0                                           nan                 -43.76210000
# 1                                           nan                 -43.56128300
# 2                                           nan                 -44.03161600
# 3                                           nan                 -43.99991000
# 4                                           nan                 -43.48729700
# ...                                         ...                          ...
# 25261                               36.17495398                 -42.67346600
# 25262                               36.17495398                 -42.50964000
# 25263                               36.17495399                 -42.76330000
# 25264                               36.17495399                 -42.74744800
# 25265                               36.17495396                 -42.62061700
#
#        IMU_ATTI(0):alti:D[meters]  IMU_ATTI(0):relativeHeight:C[meters]  \
# 0                    -44.09289000                                   nan
# 1                    -44.09327300                                   nan
# 2                    -44.07071700                                   nan
# 3                    -44.05832000                                   nan
# 4                    -44.05737700                                   nan
# ...                           ...                                   ...
# 25261                -45.47008500                            2.81074527
# 25262                -45.47198500                            2.97457126
# 25263                -45.46957400                            2.72090915
# 25264                -45.47207600                            2.73676303
# 25265                -45.47884400                            2.86359409
#
#        IMU_ATTI(0):absoluteHeight:C[meters]  IMU_ATTI(0):numSats  \
# 0                                       nan                    8
# 1                                       nan                    8
# 2                                       nan                    8
# 3                                       nan                    8
# 4                                       nan                    8
# ...                                     ...                  ...
# 25261                                   nan                   18
# 25262                                   nan                   18
# 25263                                   nan                   18
# 25264                                   nan                   18
# 25265                                   nan                   18
#
#        IMU_ATTI(0):roll:C[degrees [-180;180]]  ...  BatteryInfo:BatCurrent:D  \
# 0                                 -0.34243875  ...                      -620
# 1                                 -0.34326232  ...                      -620
# 2                                 -0.34092792  ...                      -620
# 3                                 -0.34247673  ...                      -620
# 4                                 -0.30563588  ...                      -620
# ...                                       ...  ...                       ...
# 25261                              0.37306199  ...                     -7640
# 25262                              0.37327935  ...                     -7640
# 25263                              0.37287694  ...                     -7640
# 25264                              0.36525744  ...                     -7640
# 25265                              0.36016237  ...                     -7640
#
#        BatteryInfo:BatCap:D  BatteryInfo:CapPercnt:D  BatteryInfo:BatTemp:D  \
# 0                      9652                       92                    329
# 1                      9652                       92                    329
# 2                      9652                       92                    329
# 3                      9652                       92                    329
# 4                      9652                       92                    329
# ...                     ...                      ...                    ...
# 25261                  4068                       39                    376
# 25262                  4068                       39                    376
# 25263                  4068                       39                    376
# 25264                  4068                       39                    376
# 25265                  4068                       39                    376
#
#        BatteryInfo:BatAuth:D  BatteryInfo:BatDataCnt:D  BatteryInfo:FullCap:D  \
# 0                          1                        31                  10464
# 1                          1                        31                  10464
# 2                          1                        31                  10464
# 3                          1                        31                  10464
# 4                          1                        31                  10464
# ...                      ...                       ...                    ...
# 25261                      1                       877                  10464
# 25262                      1                       877                  10464
# 25263                      1                       877                  10464
# 25264                      1                       877                  10464
# 25265                      1                       877                  10464
#
#                       Attribute|Value  ConvertDatV3  4.2.1
# 0          Firmware Date| Feb 26 2019           nan    nan
# 1                      ACType|UNKNOWN           nan    nan
# 2      dateTime|2021-4-15 2:18:10 GMT           nan    nan
# 3                                 NaN           nan    nan
# 4                                 NaN           nan    nan
# ...                               ...           ...    ...
# 25261                             NaN           nan    nan
# 25262                             NaN           nan    nan
# 25263                             NaN           nan    nan
# 25264                             NaN           nan    nan
# 25265                             NaN           nan    nan
#
# [25266 rows x 245 columns]

# %%
print(MG1S_df['GPS:dateTimeStamp'].dtype)
#BZ column
# Out:
# object

# %%
MG1S_df['GPS:dateTimeStamp']
# Out:
# 0        2021-04-15T02:18:28Z
# 1        2021-04-15T02:18:28Z
# 2        2021-04-15T02:18:28Z
# 3        2021-04-15T02:18:28Z
# 4        2021-04-15T02:18:28Z
#                  ...
# 25261    2021-04-15T02:32:35Z
# 25262    2021-04-15T02:32:35Z
# 25263    2021-04-15T02:32:35Z
# 25264    2021-04-15T02:32:35Z
# 25265    2021-04-15T02:32:35Z
# Name: GPS:dateTimeStamp, Length: 25266, dtype: object

# %%
# 시간값(object) datetime 값으로 변경하기 1
Flight_datetime = pd.to_datetime(MG1S_df['GPS:dateTimeStamp'], format = '%Y-%m-%d')

# %%
print(Flight_datetime)
# Out:
# 0       2021-04-15 02:18:28+00:00
# 1       2021-04-15 02:18:28+00:00
# 2       2021-04-15 02:18:28+00:00
# 3       2021-04-15 02:18:28+00:00
# 4       2021-04-15 02:18:28+00:00
#                    ...
# 25261   2021-04-15 02:32:35+00:00
# 25262   2021-04-15 02:32:35+00:00
# 25263   2021-04-15 02:32:35+00:00
# 25264   2021-04-15 02:32:35+00:00
# 25265   2021-04-15 02:32:35+00:00
# Name: GPS:dateTimeStamp, Length: 25266, dtype: datetime64[ns, UTC]

# %%
Flight_datetime.dtypes
# Out:
# datetime64[ns, UTC]

# %%
MG1S_df['GPS:dateTimeStamp']
# Out:
# 0       2021-04-15 02:18:28
# 1       2021-04-15 02:18:28
# 2       2021-04-15 02:18:28
# 3       2021-04-15 02:18:28
# 4       2021-04-15 02:18:28
#                 ...
# 25261   2021-04-15 02:32:35
# 25262   2021-04-15 02:32:35
# 25263   2021-04-15 02:32:35
# 25264   2021-04-15 02:32:35
# 25265   2021-04-15 02:32:35
# Name: GPS:dateTimeStamp, Length: 25266, dtype: datetime64[ns]

# %%
print(MG1S_df['GPS:dateTimeStamp'].dtype)
# Out:
# datetime64[ns]

# %%
#데이터 프레임 열 삭제
print(MG1S_df.columns)
# Out:
# Index(['Clock:Tick#', 'Clock:offsetTime',
#        'IMU_ATTI(0):Longitude[degrees [-180;180]]',
#        'IMU_ATTI(0):Latitude[degrees [-180;180]]',
#        'IMU_ATTI(0):press:D[meters]', 'IMU_ATTI(0):alti:D[meters]',
#        'IMU_ATTI(0):relativeHeight:C[meters]',
#        'IMU_ATTI(0):absoluteHeight:C[meters]', 'IMU_ATTI(0):numSats',
#        'IMU_ATTI(0):roll:C[degrees [-180;180]]',
#        ...
#        'BatteryInfo:BatCurrent:D', 'BatteryInfo:BatCap:D',
#        'BatteryInfo:CapPercnt:D', 'BatteryInfo:BatTemp:D',
#        'BatteryInfo:BatAuth:D', 'BatteryInfo:BatDataCnt:D',
#        'BatteryInfo:FullCap:D', 'Attribute|Value', 'ConvertDatV3', '4.2.1'],
#       dtype='object', length=245)

# %%
MG1S_df.head()
# Out:
#    Clock:Tick#  Clock:offsetTime  IMU_ATTI(0):Longitude[degrees [-180;180]]  \
# 0    184013124      -92.57000000                                        nan
# 1    184170945      -92.53600000                                        nan
# 2    184328651      -92.50200000                                        nan
# 3    184485197      -92.46900000                                        nan
# 4    184642037      -92.43500000                                        nan
#
#    IMU_ATTI(0):Latitude[degrees [-180;180]]  IMU_ATTI(0):press:D[meters]  \
# 0                                       nan                 -43.76210000
# 1                                       nan                 -43.56128300
# 2                                       nan                 -44.03161600
# 3                                       nan                 -43.99991000
# 4                                       nan                 -43.48729700
#
#    IMU_ATTI(0):alti:D[meters]  IMU_ATTI(0):relativeHeight:C[meters]  \
# 0                -44.09289000                                   nan
# 1                -44.09327300                                   nan
# 2                -44.07071700                                   nan
# 3                -44.05832000                                   nan
# 4                -44.05737700                                   nan
#
#    IMU_ATTI(0):absoluteHeight:C[meters]  IMU_ATTI(0):numSats  \
# 0                                   nan                    8
# 1                                   nan                    8
# 2                                   nan                    8
# 3                                   nan                    8
# 4                                   nan                    8
#
#    IMU_ATTI(0):roll:C[degrees [-180;180]]  ...  BatteryInfo:BatCurrent:D  \
# 0                             -0.34243875  ...                      -620
# 1                             -0.34326232  ...                      -620
# 2                             -0.34092792  ...                      -620
# 3                             -0.34247673  ...                      -620
# 4                             -0.30563588  ...                      -620
#
#    BatteryInfo:BatCap:D  BatteryInfo:CapPercnt:D  BatteryInfo:BatTemp:D  \
# 0                  9652                       92                    329
# 1                  9652                       92                    329
# 2                  9652                       92                    329
# 3                  9652                       92                    329
# 4                  9652                       92                    329
#
#    BatteryInfo:BatAuth:D  BatteryInfo:BatDataCnt:D  BatteryInfo:FullCap:D  \
# 0                      1                        31                  10464
# 1                      1                        31                  10464
# 2                      1                        31                  10464
# 3                      1                        31                  10464
# 4                      1                        31                  10464
#
#                   Attribute|Value  ConvertDatV3  4.2.1
# 0      Firmware Date| Feb 26 2019           nan    nan
# 1                  ACType|UNKNOWN           nan    nan
# 2  dateTime|2021-4-15 2:18:10 GMT           nan    nan
# 3                             NaN           nan    nan
# 4                             NaN           nan    nan
#
# [5 rows x 245 columns]

# %%
#garbage erase
MG1S_df = MG1S_df.drop(['Attribute|Value'], axis=1)
MG1S_df = MG1S_df.drop(['ConvertDatV3'], axis=1)
MG1S_df = MG1S_df.drop(['4.2.1'], axis=1)

# %%
MG1S_df.columns
# Out:
# Index(['Clock:Tick#', 'Clock:offsetTime',
#        'IMU_ATTI(0):Longitude[degrees [-180;180]]',
#        'IMU_ATTI(0):Latitude[degrees [-180;180]]',
#        'IMU_ATTI(0):press:D[meters]', 'IMU_ATTI(0):alti:D[meters]',
#        'IMU_ATTI(0):relativeHeight:C[meters]',
#        'IMU_ATTI(0):absoluteHeight:C[meters]', 'IMU_ATTI(0):numSats',
#        'IMU_ATTI(0):roll:C[degrees [-180;180]]',
#        ...
#        'BatteryInfo:LowVolThreshold:D', 'BatteryInfo:AdVol:D',
#        'BatteryInfo:BatVol:D', 'BatteryInfo:BatCurrent:D',
#        'BatteryInfo:BatCap:D', 'BatteryInfo:CapPercnt:D',
#        'BatteryInfo:BatTemp:D', 'BatteryInfo:BatAuth:D',
#        'BatteryInfo:BatDataCnt:D', 'BatteryInfo:FullCap:D'],
#       dtype='object', length=242)

# %%
MG1S_df.head()
# Out:
#    Clock:Tick#  Clock:offsetTime  IMU_ATTI(0):Longitude[degrees [-180;180]]  \
# 0    184013124      -92.57000000                                        nan
# 1    184170945      -92.53600000                                        nan
# 2    184328651      -92.50200000                                        nan
# 3    184485197      -92.46900000                                        nan
# 4    184642037      -92.43500000                                        nan
#
#    IMU_ATTI(0):Latitude[degrees [-180;180]]  IMU_ATTI(0):press:D[meters]  \
# 0                                       nan                 -43.76210000
# 1                                       nan                 -43.56128300
# 2                                       nan                 -44.03161600
# 3                                       nan                 -43.99991000
# 4                                       nan                 -43.48729700
#
#    IMU_ATTI(0):alti:D[meters]  IMU_ATTI(0):relativeHeight:C[meters]  \
# 0                -44.09289000                                   nan
# 1                -44.09327300                                   nan
# 2                -44.07071700                                   nan
# 3                -44.05832000                                   nan
# 4                -44.05737700                                   nan
#
#    IMU_ATTI(0):absoluteHeight:C[meters]  IMU_ATTI(0):numSats  \
# 0                                   nan                    8
# 1                                   nan                    8
# 2                                   nan                    8
# 3                                   nan                    8
# 4                                   nan                    8
#
#    IMU_ATTI(0):roll:C[degrees [-180;180]]  ...  BatteryInfo:LowVolThreshold:D  \
# 0                             -0.34243875  ...                          36000
# 1                             -0.34326232  ...                          36000
# 2                             -0.34092792  ...                          36000
# 3                             -0.34247673  ...                          36000
# 4                             -0.30563588  ...                          36000
#
#    BatteryInfo:AdVol:D  BatteryInfo:BatVol:D  BatteryInfo:BatCurrent:D  \
# 0                49421                 47687                      -620
# 1                49473                 50268                      -620
# 2                    0                 49220                      -620
# 3                49499                 47681                      -620
# 4                49499                 50271                      -620
#
#    BatteryInfo:BatCap:D  BatteryInfo:CapPercnt:D  BatteryInfo:BatTemp:D  \
# 0                  9652                       92                    329
# 1                  9652                       92                    329
# 2                  9652                       92                    329
# 3                  9652                       92                    329
# 4                  9652                       92                    329
#
#    BatteryInfo:BatAuth:D  BatteryInfo:BatDataCnt:D  BatteryInfo:FullCap:D
# 0                      1                        31                  10464
# 1                      1                        31                  10464
# 2                      1                        31                  10464
# 3                      1                        31                  10464
# 4                      1                        31                  10464
#
# [5 rows x 242 columns]

# %%
MG1S_df.to_csv('2021_04_15_MG1S_edited.csv')
