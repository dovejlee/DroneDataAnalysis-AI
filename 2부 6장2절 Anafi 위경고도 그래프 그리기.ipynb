# %%
# 데이타 시각화해야 하는 이유
# 아나피 비행 위경고도 그리기

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from collections import OrderedDict
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Anafi_df = pd.read_csv('2020_04_16_Anifi_edited.csv')
Anafi_df = pd.DataFrame.from_dict(OrderedDict(Anafi_df))

# %%
Anafi_df
# Out:
#       Unnamed: 0           FlightTimeEdit  battery_level  \
# 0              0  2020-04-16 10:57:01.000             93
# 1              1  2020-04-16 10:57:01.200             93
# 2              2  2020-04-16 10:57:01.400             93
# 3              3  2020-04-16 10:57:01.600             93
# 4              4  2020-04-16 10:57:01.800             93
# ...          ...                      ...            ...
# 6122        6122  2020-04-16 11:12:42.000             35
# 6123        6123  2020-04-16 11:12:42.100             35
# 6124        6124  2020-04-16 11:12:42.200             35
# 6125        6125  2020-04-16 11:12:42.400             35
# 6126        6126  2020-04-16 11:12:42.600             35
#
#       product_gps_latitude  product_gps_longitude  altitude
# 0                36.586979             126.375218       0.0
# 1                36.586979             126.375218       0.0
# 2                36.586979             126.375218       0.0
# 3                36.586979             126.375218       0.0
# 4                36.586979             126.375218       0.0
# ...                    ...                    ...       ...
# 6122             36.586988             126.375225       0.0
# 6123             36.586988             126.375225       0.0
# 6124             36.586988             126.375225       0.0
# 6125             36.586988             126.375224       0.0
# 6126             36.586988             126.375224       0.0
#
# [6127 rows x 6 columns]

# %%
###Series로 바꾸면서 numpy이용하여 그리기

# %%
#x = np.arange(6127)
# x= Anafi_df['FlightTime']
#x = DateTime_Ser
#x = Anafi_df['time'] - error -size 가 다름
x = np.array(Anafi_df['FlightTimeEdit'])
y = np.array(Anafi_df['product_gps_latitude'])

# %%
type(y)
# Out:
# numpy.ndarray

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array(['2020-04-16 10:57:01.000', '2020-04-16 10:57:01.200',
#        '2020-04-16 10:57:01.400', ..., '2020-04-16 11:12:42.200',
#        '2020-04-16 11:12:42.400', '2020-04-16 11:12:42.600'], dtype=object)

# %%
y
# Out:
# array([36.5869785 , 36.58697867, 36.58697867, ..., 36.58698783,
#        36.58698783, 36.58698767])

# %%
plt.plot(x,y)
plt.title("Latitude")
plt.show()

# %%
x = np.array(Anafi_df['FlightTimeEdit'])
y = np.array(Anafi_df['product_gps_longitude'])
plt.plot(x,y)
plt.title("Longitute")
plt.show()

# %%
x = np.array(Anafi_df['FlightTimeEdit'])
y = np.array(Anafi_df['altitude'])
plt.plot(x,y)
plt.title("Altituede")
plt.show()

# %%
###DataFrame으로 처리하여 그리기

# %%
# 데이타 프레임을 Series로 바꾸고.. numpy 제외 하고 그리기..
fig = plt.figure() 
axes = fig.add_subplot(1, 1, 1)
axes.set_title('latitude')
axes.set_xlabel('Time') 
axes.set_ylabel('latitude')
# 

#data = pd.DataFrame(['GPS:Time'],['Motor:Volts:Rfront:volts'])
Time = (Anafi_df['FlightTimeEdit'])
Lat = (Anafi_df['product_gps_latitude'])
plt.plot(Time, Lat)
plt.show()

# %%
fig = plt.figure() 
axes = fig.add_subplot(1, 1, 1)
axes.set_title('longitude')
axes.set_xlabel('Time') 
axes.set_ylabel('longitude')
# 

#data = pd.DataFrame(['GPS:Time'],['Motor:Volts:Rfront:volts'])
Time = (Anafi_df['FlightTimeEdit'])
Lon = (Anafi_df['product_gps_longitude'])
plt.plot(Time, Lon)
plt.show()

# %%
fig = plt.figure() 
axes = fig.add_subplot(1, 1, 1)
axes.set_title('altitude')
axes.set_xlabel('Time') 
axes.set_ylabel('altitude')
# 

Time = (Anafi_df['FlightTimeEdit'])
Alt = (Anafi_df['altitude'])
plt.plot(Time, Alt)
plt.show()
