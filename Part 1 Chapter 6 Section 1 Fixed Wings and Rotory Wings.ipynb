# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
UAV_df = pd.read_csv("data/UavSize.csv")

# %%
UAV_df
# Out:
#           Type               Company               Name  Length   Width  \
# 0    FixedWing                    XK          A100 SU27   420.0   340.0
# 1    FixedWing                 Samco           DUODRONE  1400.0  2200.0
# 2    FixedWing            Uconsystem          RemoM-002  1440.0  1800.0
# 3    FixedWing  Suewon Unmanned Tech            SCANNER  1200.0  2600.0
# 4    FixedWing            KEVA Drone        KD-2 MAPPER  1100.0  1800.0
# 5    FixedWing              Volantex              ASW28  1132.0  2540.0
# 6    FixedWing  Suewon Unmanned Tech           VAM-400X  1000.0  1400.0
# 7    FixedWing             FINEKOWAC     Canister Style  1500.0  1500.0
# 8    FixedWing                Parrot              DISCO   580.0  1150.0
# 9    FixedWing                 Samco      DUODRONE - VA  2600.0  1400.0
# 10   FixedWing                 Samco        DUODRONE-EN  3200.0  2000.0
# 11   FixedWing                 Samco        DUODRONE-WB  1200.0  3000.0
# 12   FixedWing               Beliver         1960mm UAV  1070.0  1960.0
# 13   FixedWing             Skywalker   1830mm FPV Plane  1270.0  1830.0
# 14   FixedWing             ACCESS WE       Neptune V270  1460.0  2750.0
# 15   FixedWing                   MFE           Freedman  1070.0  2100.0
# 16   FixedWing           World Model          Cherokee2  1637.0  3320.0
# 17   FixedWing                 X-UAV              Talon  1100.0  1718.0
# 18   FixedWing           SonicModell  Mini Skyhunter V2   855.0  1238.0
# 19   FixedWing                 Dyman      P-51D Mustang  1045.0  1200.0
# 20   FixedWing               Phoenix         Stinson EP   990.0  1310.0
# 21   FixedWing               Skywing       Sky rock F3A  1030.0  1000.0
# 22   FixedWing                 Dyman            Seawind  1045.0  1220.0
# 23   FixedWing           World Model  Qutrageous Racing   980.0  1320.0
# 24   FixedWing           World Model      The Big Wings  1075.0  3035.0
# 25   FixedWing                  ZETA           Z-84 EPO   405.0   845.0
# 26   FixedWing             Skywalker             falcon   620.0  1340.0
# 27   FixedWing                Ranger           EX 757-3  1170.0  1980.0
# 28  RotoryWing                   DJI       MAVIC 2 ZOOM   322.0   242.0
# 29  RotoryWing                   DJI        MAVIC 2 PRO   322.0   242.0
# 30  RotoryWing                   DJI      PHANTOM 4 PRO   289.5   289.5
# 31  RotoryWing                   DJI              SPARK   143.0   143.0
# 32  RotoryWing                   DJI          INSPIRE 2   427.0   317.0
# 33  RotoryWing                   DJI              MG-1P  1460.0  1460.0
# 34  RotoryWing               KaKBeir             SG700D   400.0   300.0
# 35  RotoryWing                 CERES                10s  1940.0  1680.0
# 36  RotoryWing                 CERES                16H  1860.0  1860.0
# 37  RotoryWing                 CERES        CERES3 Lite   365.0   365.0
# 38  RotoryWing                   EFT               G420  1974.0  2665.0
# 39  RotoryWing               intosky          PREX9-T18  1590.0  1370.0
# 40  RotoryWing                Raptor         T Quad 25E   730.0   600.0
# 41  RotoryWing             KoreanAir   Inspection Drone  1002.0  1002.0
# 42  RotoryWing                Xiaomi         FIMI X8 SE   204.0   106.0
# 43  RotoryWing                    XK               X380   305.0   305.0
# 44  RotoryWing                   DJI              mini2   159.0   203.0
# 45  RotoryWing                   EFT             EFT610  1800.0  1800.0
# 46  RotoryWing        infinity works               P6CR   860.0   760.0
# 47  RotoryWing        infinity works                 P6  1140.0  1000.0
# 48  RotoryWing        infinity works                P4A  1225.0   880.0
# 49  RotoryWing        infinity works                P4X   350.0   250.0
# 50  RotoryWing                soomvi              V-100  1000.0   482.6
# 51  RotoryWing                xdrone             XD-X8S  1100.0  1100.0
# 52  RotoryWing            Uconsystem     Remocopter-800   643.0   643.0
# 53  RotoryWing            Uconsystem     Remocopter-900   535.0   535.0
# 54  RotoryWing                 Huins          Blueye-1K   330.0   300.0
# 55  RotoryWing               ARWroks         DAMO AR-X8  1000.0  1000.0
# 56  RotoryWing                drogen        LOBIT 300GT   360.0   268.0
# 57  RotoryWing                 Enord         Kdrone-A20  2123.0  2123.0
#
#     Height  Weight
# 0      NaN      65
# 1      NaN    3200
# 2      NaN    3500
# 3      NaN    5000
# 4      NaN    2000
# 5      NaN    1050
# 6      NaN    6000
# 7      NaN   15000
# 8      NaN     750
# 9      NaN   10000
# 10     NaN   21500
# 11     NaN    9000
# 12     NaN    4200
# 13     NaN    2750
# 14     NaN   17000
# 15     NaN    5000
# 16     NaN    3780
# 17     NaN    2750
# 18     NaN     830
# 19     NaN    1100
# 20     NaN    1700
# 21     NaN     760
# 22     NaN    1250
# 23     NaN    1540
# 24     NaN    7100
# 25     NaN     300
# 26     NaN     650
# 27     NaN    1500
# 28    84.0     905
# 29    84.0     907
# 30   196.0    1375
# 31    55.0     300
# 32   425.0    3440
# 33   616.0    9700
# 34    60.0     147
# 35   460.0   14900
# 36   600.0   17100
# 37   110.0     992
# 38   868.0   18320
# 39   570.0   18500
# 40   330.0    1434
# 41   404.0    5500
# 42    72.6     790
# 43   210.0     945
# 44    56.0     249
# 45   480.0   13800
# 46   650.0    9700
# 47   650.0    9400
# 48   580.0   15000
# 49   150.0    1400
# 50   770.0   13100
# 51   860.0   13500
# 52   255.0    5250
# 53   150.0    7600
# 54   600.0    1200
# 55   600.0   10200
# 56   100.0     850
# 57   688.0   18800

# %%
UAV_df["diagonal"]= np.sqrt(UAV_df["Length"]**2 + UAV_df["Width"])

# %%
FixedWing_df = UAV_df[UAV_df["Type"]=="FixedWing"]
RotoryWing_df = UAV_df[UAV_df["Type"]=="RotoryWing"]

# %%
FixedWing_df
# Out:
#          Type               Company               Name  Length   Width  \
# 0   FixedWing                    XK          A100 SU27   420.0   340.0
# 1   FixedWing                 Samco           DUODRONE  1400.0  2200.0
# 2   FixedWing            Uconsystem          RemoM-002  1440.0  1800.0
# 3   FixedWing  Suewon Unmanned Tech            SCANNER  1200.0  2600.0
# 4   FixedWing            KEVA Drone        KD-2 MAPPER  1100.0  1800.0
# 5   FixedWing              Volantex              ASW28  1132.0  2540.0
# 6   FixedWing  Suewon Unmanned Tech           VAM-400X  1000.0  1400.0
# 7   FixedWing             FINEKOWAC     Canister Style  1500.0  1500.0
# 8   FixedWing                Parrot              DISCO   580.0  1150.0
# 9   FixedWing                 Samco      DUODRONE - VA  2600.0  1400.0
# 10  FixedWing                 Samco        DUODRONE-EN  3200.0  2000.0
# 11  FixedWing                 Samco        DUODRONE-WB  1200.0  3000.0
# 12  FixedWing               Beliver         1960mm UAV  1070.0  1960.0
# 13  FixedWing             Skywalker   1830mm FPV Plane  1270.0  1830.0
# 14  FixedWing             ACCESS WE       Neptune V270  1460.0  2750.0
# 15  FixedWing                   MFE           Freedman  1070.0  2100.0
# 16  FixedWing           World Model          Cherokee2  1637.0  3320.0
# 17  FixedWing                 X-UAV              Talon  1100.0  1718.0
# 18  FixedWing           SonicModell  Mini Skyhunter V2   855.0  1238.0
# 19  FixedWing                 Dyman      P-51D Mustang  1045.0  1200.0
# 20  FixedWing               Phoenix         Stinson EP   990.0  1310.0
# 21  FixedWing               Skywing       Sky rock F3A  1030.0  1000.0
# 22  FixedWing                 Dyman            Seawind  1045.0  1220.0
# 23  FixedWing           World Model  Qutrageous Racing   980.0  1320.0
# 24  FixedWing           World Model      The Big Wings  1075.0  3035.0
# 25  FixedWing                  ZETA           Z-84 EPO   405.0   845.0
# 26  FixedWing             Skywalker             falcon   620.0  1340.0
# 27  FixedWing                Ranger           EX 757-3  1170.0  1980.0
#
#     Height  Weight     diagonal
# 0      NaN      65   420.404567
# 1      NaN    3200  1400.785494
# 2      NaN    3500  1440.624864
# 3      NaN    5000  1201.082845
# 4      NaN    2000  1100.817878
# 5      NaN    1050  1133.121353
# 6      NaN    6000  1000.699755
# 7      NaN   15000  1500.499917
# 8      NaN     750   580.990533
# 9      NaN   10000  2600.269217
# 10     NaN   21500  3200.312485
# 11     NaN    9000  1201.249350
# 12     NaN    4200  1070.915496
# 13     NaN    2750  1270.720268
# 14     NaN   17000  1460.941477
# 15     NaN    5000  1070.980859
# 16     NaN    3780  1638.013736
# 17     NaN    2750  1100.780632
# 18     NaN     830   855.723670
# 19     NaN    1100  1045.574005
# 20     NaN    1700   990.661395
# 21     NaN     760  1030.485323
# 22     NaN    1250  1045.583569
# 23     NaN    1540   980.673238
# 24     NaN    7100  1076.410702
# 25     NaN     300   406.041870
# 26     NaN     650   621.079705
# 27     NaN    1500  1170.845848

# %%
RotoryWing_df
# Out:
#           Type         Company              Name  Length   Width  Height  \
# 28  RotoryWing             DJI      MAVIC 2 ZOOM   322.0   242.0    84.0
# 29  RotoryWing             DJI       MAVIC 2 PRO   322.0   242.0    84.0
# 30  RotoryWing             DJI     PHANTOM 4 PRO   289.5   289.5   196.0
# 31  RotoryWing             DJI             SPARK   143.0   143.0    55.0
# 32  RotoryWing             DJI         INSPIRE 2   427.0   317.0   425.0
# 33  RotoryWing             DJI             MG-1P  1460.0  1460.0   616.0
# 34  RotoryWing         KaKBeir            SG700D   400.0   300.0    60.0
# 35  RotoryWing           CERES               10s  1940.0  1680.0   460.0
# 36  RotoryWing           CERES               16H  1860.0  1860.0   600.0
# 37  RotoryWing           CERES       CERES3 Lite   365.0   365.0   110.0
# 38  RotoryWing             EFT              G420  1974.0  2665.0   868.0
# 39  RotoryWing         intosky         PREX9-T18  1590.0  1370.0   570.0
# 40  RotoryWing          Raptor        T Quad 25E   730.0   600.0   330.0
# 41  RotoryWing       KoreanAir  Inspection Drone  1002.0  1002.0   404.0
# 42  RotoryWing          Xiaomi        FIMI X8 SE   204.0   106.0    72.6
# 43  RotoryWing              XK              X380   305.0   305.0   210.0
# 44  RotoryWing             DJI             mini2   159.0   203.0    56.0
# 45  RotoryWing             EFT            EFT610  1800.0  1800.0   480.0
# 46  RotoryWing  infinity works              P6CR   860.0   760.0   650.0
# 47  RotoryWing  infinity works                P6  1140.0  1000.0   650.0
# 48  RotoryWing  infinity works               P4A  1225.0   880.0   580.0
# 49  RotoryWing  infinity works               P4X   350.0   250.0   150.0
# 50  RotoryWing          soomvi             V-100  1000.0   482.6   770.0
# 51  RotoryWing          xdrone            XD-X8S  1100.0  1100.0   860.0
# 52  RotoryWing      Uconsystem    Remocopter-800   643.0   643.0   255.0
# 53  RotoryWing      Uconsystem    Remocopter-900   535.0   535.0   150.0
# 54  RotoryWing           Huins         Blueye-1K   330.0   300.0   600.0
# 55  RotoryWing         ARWroks        DAMO AR-X8  1000.0  1000.0   600.0
# 56  RotoryWing          drogen       LOBIT 300GT   360.0   268.0   100.0
# 57  RotoryWing           Enord        Kdrone-A20  2123.0  2123.0   688.0
#
#     Weight     diagonal
# 28     905   322.375557
# 29     907   322.375557
# 30    1375   289.999569
# 31     300   143.499129
# 32    3440   427.371033
# 33    9700  1460.499914
# 34     147   400.374824
# 35   14900  1940.432941
# 36   17100  1860.499933
# 37     992   365.499658
# 38   18320  1974.674910
# 39   18500  1590.430759
# 40    1434   730.410843
# 41    5500  1002.499875
# 42     790   204.259639
# 43     945   305.499591
# 44     249   159.637088
# 45   13800  1800.499931
# 46    9700   860.441747
# 47    9400  1140.438512
# 48   15000  1225.359131
# 49    1400   350.356961
# 50   13100  1000.241271
# 51   13500  1100.499886
# 52    5250   643.499806
# 53    7600   535.499767
# 54    1200   330.454233
# 55   10200  1000.499875
# 56     850   360.372030
# 57   18800  2123.499941

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,1,1)
axes2 = fig.add_subplot(2,1,2)
axes1.plot(FixedWing_df["Length"], FixedWing_df["Weight"], 'o',c ="red")
axes2.plot(RotoryWing_df["Length"], RotoryWing_df["Weight"], 'o', c ='blue' )
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
axes1.set_title("Fixed Wing")
axes2.set_title("Rotory Wing")
axes2.set_xlim(axes1.get_xlim())
fig.suptitle("UAV Size <Length-Weight>")
fig
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,1,1)
axes2 = fig.add_subplot(2,1,2)
axes1.plot(FixedWing_df["Length"], FixedWing_df["Width"], 'o',c ="red")
axes2.plot(RotoryWing_df["Length"], RotoryWing_df["Width"], 'o', c ='blue' )
axes1.set_title("Fixed Wing")
axes2.set_title("Rotory Wing")
fig.suptitle("UAV Size <Length-Width>")
axes2.set_xlim(axes1.get_xlim())
axes2.set_ylim(axes1.get_xlim())
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,1,1)
axes2 = fig.add_subplot(2,1,2)
axes1.plot(FixedWing_df["Width"], FixedWing_df["Length"], 'o',c ="red")
axes2.plot(RotoryWing_df["Width"], RotoryWing_df["Length"], 'o', c ='blue' )
axes1.set_title("Fixed Wing")
axes2.set_title("Rotory Wing")
fig.suptitle("UAV Size <Width - Length>")
axes2.set_xlim(axes1.get_xlim())
axes2.set_ylim(axes1.get_xlim())
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,1,1)
axes2 = fig.add_subplot(2,1,2)
axes1.plot(FixedWing_df["diagonal"], FixedWing_df["Weight"], 'o',c ="red")
axes2.plot(RotoryWing_df["diagonal"], RotoryWing_df["Weight"], 'o', c ='blue' )
axes1.set_title("Fixed Wing")
axes2.set_title("Rotory Wing")
fig.suptitle("UAV Size <Diagonal- Weight>")
axes2.set_xlim(axes1.get_xlim())
axes2.set_ylim(axes1.get_xlim())
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
